# %% [markdown]
# # 2. Praktikum 1: Eksperimen Tipe Data List <br>
# Selesaikan langkah-langkah praktikum berikut ini menggunakan VS Code atau Code Editor favorit Anda.

# %% [markdown]
# **Langkah 1:**<br>
# Ketik atau salin kode program berikut ke dalam void main(). <br>
#
#
# ```
# var list = [1, 2, 3];
# assert(list.length == 3);
# assert(list[1] == 2);
# print(list.length);
# print(list[1]);
#
# list[1] = 1;
# assert(list[1] == 1);
# print(list[1]);
# ```

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jawab : <br>
# **Langkah 2:** <br>
# Silakan coba eksekusi (Run) kode pada langkah 1 tersebut. Apa yang terjadi? Jelaskan! <br>
# ![image.png](data:image/png;base64,...) <br>
# <p align="justify"> Penjelasan : Jadi kita mempunya sebuah variable list bernama list yang mempunyai panjang index 3, yang mana pada awal print, kita memprint panjang index, lalu print kedua kita memprint index ke 1 yaitu 2, kemudian kita mengubah index ke 1 menjadi 1 dan pada print terakhir kita memprint index ke 1 lagi dengan nilai 1 setelah kita ubah

# %% [markdown]
# **Langkah 3:** <br>
# Ubah kode pada langkah 1 menjadi variabel final yang mempunyai index = 5 dengan default value = null. Isilah nama dan NIM Anda pada elemen index ke-1 dan ke-2. Lalu print dan capture hasilnya. <br> <br>
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki. <br>

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Penjelasan : Tidak terjadi error, seperti penjelasan diatas namun pada list kali ini kita mempunyai 5 index

# %% [markdown]
# **Catatan:** <br>
# Dart akan melakukan infers pada variabel list dengan tipe data List. Jika Anda mencoba menambahkan elemen berupa objek non-integer pada list, maka analyzer atau runtime akan error. Informasi lebih lanjut dapat membaca di tautan ini [type inference.](https://dart.dev/language/type-system#type-inference)

# %% [markdown]
# # 3. Praktikum 2: Eksperimen Tipe Data Set <br>
# Selesaikan langkah-langkah praktikum berikut ini menggunakan VS Code atau Code Editor favorit Anda. <br>

# %% [markdown]
# **Langkah 1:** <br>
# Ketik atau salin kode program berikut ke dalam fungsi main(). <br>
#
#
# ```
# var halogens = {'fluorine', 'chlorine', 'bromine', 'iodine', 'astatine'};
# print(halogens);
# ```

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Langkah 2:** <br>
# Silakan coba eksekusi (Run) kode pada langkah 1 tersebut. Apa yang terjadi? Jelaskan! Lalu perbaiki jika terjadi error.

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Penjelasan : Tidak terjadi error, jadi pada list dengan nama halogens mempunyai panjang index 5

# %% [markdown]
# **Langkah 3:** <br>
# Tambahkan kode program berikut, lalu coba eksekusi (Run) kode Anda.
#
#
# ```
# var names1 = <String>{};
# Set<String> names2 = {}; // This works, too.
# var names3 = {}; // Creates a map, not a set.
#
# print(names1);
# print(names2);
# print(names3);
# ```
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki namun tetap menggunakan ketiga variabel tersebut. Tambahkan elemen nama dan NIM Anda pada kedua variabel Set tersebut dengan dua fungsi berbeda yaitu .add() dan .addAll(). Untuk variabel Map dihapus, nanti kita coba di praktikum selanjutnya. <br> <br>
# Dokumentasikan code dan hasil di console, lalu buat laporannya.

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Penjeleasan : yang terjadi diatas kita hanya mendeklarasi variable set dengan nama names1 dengan type data string, lalau names2, kemudian names3, yang variable tersebut belum mempunyai data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Praktikum 3: Eksperimen Tipe Data Maps <br>
# Selesaikan langkah-langkah praktikum berikut ini menggunakan VS Code atau Code Editor favorit Anda. <br>

# %% [markdown]
# **Langkah 1:** <br>
# Ketik atau salin kode program berikut ke dalam fungsi main(). <br>
#
#
# ```
# var gifts = {
#   // Key:    Value
#   'first': 'partridge',
#   'second': 'turtledoves',
#   'fifth': 1
# };
#
# var nobleGases = {
#   2: 'helium',
#   10: 'neon',
#   18: 2,
# };
#
# print(gifts);
# print(nobleGases);
# ```

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Langkah 2:** <br>
# Silakan coba eksekusi (Run) kode pada langkah 1 tersebut. Apa yang terjadi? Jelaskan! Lalu perbaiki jika terjadi error.

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Penjelasan : Jadi kita mendeklarasikan 2 varibale yaitu gifts dan nobleGases yang mana kedua variable tersebut menggunakan metode maps

# %% [markdown]
# **Langkah 3:** <br>
# Tambahkan kode program berikut, lalu coba eksekusi (Run) kode Anda. <br>
#
#
# ```
# var mhs1 = Map<String, String>();
# gifts['first'] = 'partridge';
# gifts['second'] = 'turtledoves';
# gifts['fifth'] = 'golden rings';
#
# var mhs2 = Map<int, String>();
# nobleGases[2] = 'helium';
# nobleGases[10] = 'neon';
# nobleGases[18] = 'argon';
# ```
#
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki. <br>
#
# Tambahkan elemen nama dan NIM Anda pada tiap variabel di atas (gifts, nobleGases, mhs1, dan mhs2). Dokumentasikan hasilnya dan buat laporannya!

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p align="justify"> Penjelasan : Pada langkah 3 kita menambahkan 2 variable baru yaitu mhs1
# dengan ketentuan map yaitu key dan value bertipe string dan mhs2 dengan ketentuan map yaitu key bertipe int dan value bertipe string yang mana isi dari mhs1 mengubah data dari variable gifts dan msh2 mengubah data dari nobleGases

# %% [markdown]
# # 5. Praktikum 4: Eksperimen Tipe Data List: Spread dan Control-flow Operators <br>
# Selesaikan langkah-langkah praktikum berikut ini menggunakan VS Code atau Code Editor favorit Anda.

# %% [markdown]
# **Langkah 1:** <br>
# Ketik atau salin kode program berikut ke dalam fungsi main(). <br>
#
#
# ```
# var list = [1, 2, 3];
# var list2 = [0, ...list];
# print(list1);
# print(list2);
# print(list2.length);
# ```

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Langkah 2:** <br>
# Silakan coba eksekusi (Run) kode pada langkah 1 tersebut. Apa yang terjadi? Jelaskan! Lalu perbaiki jika terjadi error.

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Penjelasan : ...**namaVar** berfungsi untuk mengambil data yang ada pada **namaVar**, pada kasus diatas kita mengopy data dari list1 dengan menggunakan ...**list1** yang diisikan pada list2, sehingga list2 mempunyai panjang 4

# %% [markdown]
# **Langkah 3:** <br>
# Tambahkan kode program berikut, lalu coba eksekusi (Run) kode Anda. <br>
#
#
# ```
# list1 = [1, 2, null];
# print(list1);
# var list3 = [0, ...?list1];
# print(list3.length);
# ```
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki. <br> <br>
# Tambahkan variabel list berisi NIM Anda menggunakan Spread Operators. Dokumentasikan hasilnya dan buat laporannya!

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p align="justify">
#  Penjelasan : Pada kasus error diatas kita tidak menambahkan data null ke type data int, jadi untuk memasukkan data null ke type data int disini saya mengganti type data list1 menjadi dynamic, kemudian fungsi dari ...?list1 adalah null-aware atau data null akan ikut terhitung

# %% [markdown]
# **Langkah 4:** <br>
# Tambahkan kode program berikut, lalu coba eksekusi (Run) kode Anda. <br>
#
#
# ```
# var nav = ['Home', 'Furniture', 'Plants', if (promoActive) 'Outlet'];
# print(nav);
# ```
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki. Tunjukkan hasilnya jika variabel promoActive ketika true dan false.

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Penjelasan : jika promoActive bernilai true maka outlet akan ditambahkan namaun jika flase maka tidak ditambahkan

# %% [markdown]
# **Langkah 5:** <br>
# Tambahkan kode program berikut, lalu coba eksekusi (Run) kode Anda. <br>
#
#
# ```
# var nav2 = ['Home', 'Furniture', 'Plants', if (login case 'Manager') 'Inventory'];
# print(nav2);
# ```
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki. Tunjukkan hasilnya jika variabel login mempunyai kondisi lain.

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p align="justify">
# Penjelasan : jika variable login memiliki value 'Manager' makan case akan bernilai true, namun jika variable login memiliki value selain 'Manager' maka case akan bernilai false

# %% [markdown]
# **Langkah 6:** <br>
# Tambahkan kode program berikut, lalu coba eksekusi (Run) kode Anda. <br>
#
#
# ```
# var listOfInts = [1, 2, 3];
# var listOfStrings = ['#0', for (var i in listOfInts) '#$i'];
# assert(listOfStrings[1] == '#1');
# print(listOfStrings);
# ```
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki. Jelaskan manfaat Collection For dan dokumentasikan hasilnya.

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Penjelasan : disini kita menggunakan perulangan for-in dengan data listOfInts dengan mendeklarasikan var i

# %% [markdown]
# # 6. Praktikum 5: Eksperimen Tipe Data Records

# %% [markdown]
# **Catatan**: Tipe data Records mulai diperkenalkan pada Dart versi 3.0. Pastikan Anda sudah setup menggunakan Dart 3.0 atau yang lebih baru.

# %% [markdown]
# Selesaikan langkah-langkah praktikum berikut ini menggunakan VS Code atau Code Editor favorit Anda.

# %% [markdown]
# **Langkah 1:** <br>
# Ketik atau salin kode program berikut ke dalam fungsi main(). <br>
#
#
# ```
# var record = ('first', a: 2, b: true, 'last');
# print(record)
# ```

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Langkah 2:** <br>
# Silakan coba eksekusi (Run) kode pada langkah 1 tersebut. Apa yang terjadi? Jelaskan! Lalu perbaiki jika terjadi error.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p align="justify">
# Penjelasan : Record dapat menampung semua janis data (termasuk map), urutan pembacaannya urut kecuali data bertype map, data bertype map akan dibaca paling akhir

# %% [markdown]
# **Langkah 3:** <br>
# Tambahkan kode program berikut di luar scope void main(), lalu coba eksekusi (Run) kode Anda. <br>
#
#
# ```
# (int, int) tukar((int, int) record) {
#   var (a, b) = record;
#   return (b, a);
# }
# ```
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki. Gunakan fungsi tukar() di dalam main() sehingga tampak jelas proses pertukaran value field di dalam Records.

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p align="justify">
# Penjelasan : Code yang ada diatas hanya deklarasi sebuah fungsi dengan type data tuple, fungsi tersbut bertugas untuk menukan posisi dari data tuple, pada kasus ini saya memutar posisi dari data tuple dengan nama aku

# %% [markdown]
# **Langkah 4:** <br>
# Tambahkan kode program berikut di dalam scope void main(), lalu coba eksekusi (Run) kode Anda. <br>
#
#
# ```
# // Record type annotation in a variable declaration:
# (String, int) mahasiswa;
# print(mahasiswa);
# ```
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki. Inisialisasi field nama dan NIM Anda pada variabel record mahasiswa di atas. Dokumentasikan hasilnya dan buat laporannya!

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p align="justify">
# Penjelasan : Variable mahasiswa dengan type data tuple dengan ketentuan data String, int, error diatas terjadi karena kita belum memberi value pada mahasiswa

# %% [markdown]
# **Langkah 5:** <br>
# Tambahkan kode program berikut di dalam scope void main(), lalu coba eksekusi (Run) kode Anda. <br>
#
#
# ```
# var mahasiswa2 = ('first', a: 2, b: true, 'last');
#
# print(mahasiswa2.$1); // Prints 'first'
# print(mahasiswa2.a); // Prints 2
# print(mahasiswa2.b); // Prints true
# print(mahasiswa2.$2); // Prints 'last'
# ```
# Apa yang terjadi ? Jika terjadi error, silakan perbaiki. Gantilah salah satu isi record dengan nama dan NIM Anda, lalu dokumentasikan hasilnya dan buat laporannya!

# %% [markdown]
# Jawab : <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.   Silakan selesaikan Praktikum 1 sampai 5, lalu dokumentasikan berupa screenshot hasil pekerjaan Anda beserta penjelasannya!

# %% [markdown]
# Jawab : Saya sudah menjawab semua pertanyaan

# %% [markdown]
# 2.   Jelaskan yang dimaksud Functions dalam bahasa Dart!

# %% [markdown]
# <p align="justify">Jawab : blok kode yang dapat digunakan untuk melakukan tugas tertentu atau menghitung nilai dan dapat dipanggil atau dieksekusi dari tempat lain dalam kode

# %% [markdown]
# 3.   Jelaskan jenis-jenis parameter di Functions beserta contoh sintaksnya!

# %% [markdown]
# Jawab : <br>
#
#
# *   Positional Prameters <br>
#
# ```
# void cetakInfo(String nama, int usia) {
#   print('Nama: $nama, Usia: $usia');
# }
# ```
# *   Named Parameters  <br>
#
# ```
# void cetakInfo({String nama, int usia}) {
#   print('Nama: $nama, Usia: $usia');
# }
# ```
# *   Default Parameters <br>
#
# ```
# void cetakInfo({String nama = 'Tidak Ada Nama', int usia = 0}) {
#   print('Nama: $nama, Usia: $usia');
# }
# ```
# *   Required Parameters  <br>
#
# ```
# void cetakInfo({required String nama, required int usia}) {
#   print('Nama: $nama, Usia: $usia');
# }
# ```
# *   Rest Parameters  <br>
#
# ```
# void tampilkanHobi(String nama, String pekerjaan, {required String... hobi}) {
#   print('Nama: $nama, Pekerjaan: $pekerjaan');
#   print('Hobi: $hobi');
# }
# ```

# %% [markdown]
# 4. Jelaskan maksud Functions sebagai first-class objects beserta contoh sintaknya!

# %% [markdown]
# Jawab : Function di dalam Dart dapat di passing ke parameter dari function lainnya. <br>
#
#
# ```
# # This is forvoid main(List<String> args) {
#   //Function yang dipassing ke parameter function lainnya.
#   void printElement(int element) => print(element);
#   //Function yang di assign ke variabel
#   final filter = (int element) => element.isOdd;
#   List.generate(100, (index) => index + 1).where(filter).forEach(printElement);
# }matted as code
# ```

# %% [markdown]
# 5. Apa itu Anonymous Functions? Jelaskan dan berikan contohnya!

# %% [markdown]
# <p align="justify">Jawab : Sebuah function yang tidak memiliki nama, biasanya function mempunyai nama, contoh main() dimana main merupakan namanya. Anonymous function biasa dikenal dengan lamba atau closure di dalam bahasa pemrograman lain. <br>
#
#
# ```
# # This is fovoid main(List<String> args) {
#   List.generate(100, (index) => index + 1)
#       .where((int item) => item.isEven)
#       .forEach((int element) => print('Value: $element'));
# }rmatted as code
# ```

# %% [markdown]
# 6. Jelaskan perbedaan Lexical scope dan Lexical closures! Berikan contohnya!

# %% [markdown]
# Jawab : Dart adalah bahasa yang dibatasi leksikal, yang berarti bahwa ruang lingkup variabel ditentukan secara statis, hanya dengan letak kode, lalu Closure adalah sebuah function yang memiliki akses ke variabel dalam lingkup leksikalnya, bahkan fungsi tersebut digunakan di luar lingkup aslinya. <br> <br>
# **Lexical Scope** <br>
#
#
# ```
# bool topLevel = true;
#
# void main(List<String> args) {
#   bool insideMain = topLevel;
#
#   void function() {
#     bool insideFunction = insideMain;
#   }
# }
# ```
# **Lexical Closure** <br>
#
#
# ```
# Function addWithTen(int number) => (int amount) => number + amount + 10;
#
# void main(List<String> args) {
#   final count = addWithTen(1);
#   final digit = addWithTen(2);
#
#   print([count(1), digit(2)]);
#   //Output: [12, 14]
# }
# ```

# %% [markdown]
# 7. Jelaskan dengan contoh cara membuat return multiple value di Functions!

# %% [markdown]
# Dalam bahasa pemrograman Dart, Anda dapat mengembalikan multiple value dari sebuah fungsi dengan menggabungkannya dalam sebuah objek atau tuple. Cara yang paling umum adalah menggunakan objek Map atau objek yang ditentukan sendiri.
#
# ```
# void main() {
#   Tuple3<String, int, bool> getPersonInfo() {
#     String name = "John";
#     int age = 30;
#     bool isStudent = false;
#
#     return Tuple3(name, age, isStudent);
#   }
#
#   // Memanggil fungsi getPersonInfo()
#   Tuple3<String, int, bool> personInfo = getPersonInfo();
#
#   // Mengakses multiple value yang dikembalikan
#   String name = personInfo.item1;
#   int age = personInfo.item2;
#   bool isStudent = personInfo.item3;
#
#   print("Name: $name");
#   print("Age: $age");
#   print("Is Student: $isStudent");
# }
# ```
#
# Pada contoh diatas, kita menggunakan pustaka eksternal seperti tuple untuk mendefinisikan tipe data tuple dan mengembalikannya dari fungsi. Kemudian, kita dapat mengakses nilai-nilai tuple menggunakan item1, item2, dan item3.

# %% [markdown]
# 8. Kumpulkan berupa link commit repo GitHub pada tautan yang telah disediakan di grup Telegram!
